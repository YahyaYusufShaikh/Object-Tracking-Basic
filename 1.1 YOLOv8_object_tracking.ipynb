# %%
# Trackers: BOTSORT , BYTETRACK

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.3/716.3 kB 4.2 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from ultralytics import YOLO
import cv2
import cv2 as cv
model = YOLO('yolov8n.pt')
results=model.track(source="C:/Users/HP EliteBook/Downloads/videoplayback.mp4", conf=0.5, iou=0.5, save=True)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/130) C:\Users\HP EliteBook\Downloads\videoplayback.mp4: 384x640 8 persons, 106.5ms
# video 1/1 (frame 2/130) C:\Users\HP EliteBook\Downloads\videoplayback.mp4: 384x640 8 persons, 70.5ms
# video 1/1 (frame 3/130) C:\Users\HP EliteBook\Downloads\videoplayback.mp4: 384x640 8 persons, 67.8ms
# video 1/1 (frame 4/130) C:\Users\HP EliteBook\Downloads\videoplayback.mp4: 384x640 8 persons, 75.9ms
# ...

# %%
#results=model.track(source="C:/Users/HP EliteBook/Downloads/demo1.mp4", conf=0.5, iou=0.5, save=True)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/486) C:\Users\HP EliteBook\Downloads\demo1.mp4: 384x640 1 person, 147.0ms
# video 1/1 (frame 2/486) C:\Users\HP EliteBook\Downloads\demo1.mp4: 384x640 1 person, 87.0ms
# video 1/1 (frame 3/486) C:\Users\HP EliteBook\Downloads\demo1.mp4: 384x640 1 person, 92.0ms
# video 1/1 (frame 4/486) C:\Users\HP EliteBook\Downloads\demo1.mp4: 384x640 1 person, 88.0ms
# ...

# %%
import cv2

# Create a VideoCapture object and read from input file
cap = cv2.VideoCapture("C:/Users/HP EliteBook/Downloads/videoplayback.avi")

# Check if camera opened successfully
if (cap.isOpened()== False):
    print("Error opening video file")

# Read until video is completed
while(cap.isOpened()):
    
# Capture frame-by-frame
    ret, frame = cap.read()
    if ret == True:
    # Display the resulting frame
        cv2.imshow('Frame', frame)
        
    # Press Q on keyboard to exit
        if cv2.waitKey(25) & 0xFF == ord('q'):
            break

# Break the loop
    else:
        break
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
